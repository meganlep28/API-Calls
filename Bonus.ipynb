# %%
# !pip install yfinance
import yfinance as yf

data = yf.download('LAC','2023-02-22','2023-02-27')
import matplotlib.pyplot as plt
# %matplotlib inline

data['Adj Close'].plot()
plt.show()
# Out:
# ...
# [*********************100%***********************]  1 of 1 completed
